# %% [markdown]
# # ViZDoom DRL Training on Google Colab
#
# This notebook will help you train and compare different DRL agents using Google Colab's GPU resources.

# %%
# Mount Google Drive (for saving checkpoints)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Install required packages
# !pip install vizdoom
# !pip install gymnasium
# !pip install wandb
# !pip install torch torchvision torchaudio
# !pip install opencv-python
# !pip install tqdm
# !pip install stable-baselines3
# !pip install matplotlib
# !pip install tensorboard

# %%
# Clone the repository
# !git clone https://github.com/your-username/VizDoom-DRL-task2.git
# %cd VizDoom-DRL-task2

# %%
# Create necessary directories
# !mkdir -p scenarios
# !mkdir -p checkpoints

# %%
# Download scenario files
# !wget https://github.com/mwydmuch/ViZDoom/raw/master/scenarios/basic.wad -O scenarios/basic.wad
# !wget https://github.com/mwydmuch/ViZDoom/raw/master/scenarios/basic.cfg -O scenarios/basic.cfg

# %% [markdown]
# ## Training CNN-DQN Agent

# %%
# Set up CUDA
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# %%
# Train CNN-DQN
# !python -m agents.cnn_dqn.train

# %% [markdown]
# ## Training Transformer-PPO Agent

# %%
# Train Transformer-PPO
# !python -m agents.transformer_ppo.train

# %% [markdown]
# ## Training Hybrid-SAC Agent

# %%
# Train Hybrid-SAC
# !python -m agents.hybrid_sac.train

# %% [markdown]
# ## Compare Agents

# %%
# Compare all agents
# !python compare_agents.py

# %%
# Save checkpoints to Google Drive
# !cp -r checkpoints /content/drive/MyDrive/VizDoom-DRL-task2/
